# %%
#importing the necessary libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt


import datetime as dt
import urllib.request, json
import os


from sklearn.preprocessing import MinMaxScaler

# %%
#reading the dataset
df = pd.read_csv("C:/Users/shafi/Downloads/NIFTY_F1_Xm8mAtb.txt")

# %%
# storing this dataframe in a csv file
df.to_csv('C:/Users/shafi/Downloads/NIFTY_F1_Xm8mAtb.csv', 
                  index = None)

# %%
df.head()
# Out:
#   BANKNIFTY      DATE   TIME    OPEN     HIGH      LOW    CLOSE  VOLUME
# 0  NIFTY_F1  20120102  09:16  4638.0  4638.00  4616.05  4626.20  212950
# 1  NIFTY_F1  20120102  09:17  4626.0  4628.00  4622.30  4625.30  107550
# 2  NIFTY_F1  20120102  09:18  4625.3  4635.55  4625.30  4635.55   81950
# 3  NIFTY_F1  20120102  09:19  4635.7  4639.70  4634.00  4638.20   79350
# 4  NIFTY_F1  20120102  09:20  4638.5  4639.90  4637.45  4638.90   72100

# %%
df.shape
# Out:
# (92480, 8)

# %%
df1=df.head(1000)

# %%
plt.figure(figsize = (18,9))
plt.plot(range(df1.shape[0]),(df1['LOW']+df1['HIGH'])/2.0)
plt.xticks(range(0,df1.shape[0],500),df1['DATE'].loc[::500],rotation=45)
plt.xlabel('DATE',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.show()

# %%
 X =df1.drop(['DATE','TIME'],axis=1)
 Y =df1['TIME']

# %%
#train test split
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.3, random_state = 42) 
X_train.shape,X_test.shape
# Out:
# ((700, 6), (300, 6))

# %%
import plotly.express as px # visualization library
from plotly.offline import init_notebook_mode, iplot # plotly offline mode
init_notebook_mode(connected=True) 
import plotly.graph_objs as go # plotly graphical object

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directo
# import warnings library
import warnings        
# ignore filters
warnings.filterwarnings("ignore") # if there is a warning after some codes, this will avoid us to see them.
plt.style.use('ggplot') # style of plots. ggplot is one of the most used style, I also like it.
# Any results you write to the current directory are saved as output.
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # SOME VISUALISATION OF FIRST HUNDRED ROWS

# %%
df2=df.head(100)

# %%
import seaborn as sns

# %%
print(df2['VOLUME'].value_counts())
plt.figure(figsize=(22,10))
sns.countplot(df2['VOLUME'])
plt.xticks(rotation=90)
plt.show()
# Out:
# 13400    2
# 39450    2
# 13600    2
# 42200    2
# 30900    2
#         ..
# 11950    1
# 19000    1
# 35300    1
# 6200     1
# 29500    1
# Name: VOLUME, Length: 95, dtype: int64

# %%
print(df2['CLOSE'].value_counts())
plt.figure(figsize=(22,10))
sns.countplot(df2['CLOSE'])
plt.xticks(rotation=90)
plt.show()
# Out:
# 4629.50    3
# 4626.00    3
# 4627.00    3
# 4625.00    2
# 4653.25    2
#           ..
# 4623.35    1
# 4625.30    1
# 4645.05    1
# 4629.45    1
# 4635.55    1
# Name: CLOSE, Length: 83, dtype: int64

# %%
print(df2['OPEN'].value_counts())
plt.figure(figsize=(22,10))
sns.countplot(df2['OPEN'])
plt.xticks(rotation=90)
plt.show()
# Out:
# 4638.00    4
# 4626.00    3
# 4627.50    3
# 4628.00    3
# 4627.45    2
#           ..
# 4630.50    1
# 4633.00    1
# 4625.65    1
# 4650.65    1
# 4630.00    1
# Name: OPEN, Length: 85, dtype: int64

# %%
print(df2['HIGH'].value_counts())
plt.figure(figsize=(22,10))
sns.countplot(df2['HIGH'])
plt.xticks(rotation=90)
plt.show()
# Out:
# 4628.00    4
# 4630.00    3
# 4649.00    3
# 4626.00    2
# 4622.75    2
#           ..
# 4653.25    1
# 4625.00    1
# 4642.10    1
# 4629.90    1
# 4635.55    1
# Name: HIGH, Length: 79, dtype: int64

# %%
print(df2['LOW'].value_counts())
plt.figure(figsize=(22,10))
sns.countplot(df2['LOW'])
plt.xticks(rotation=90)
plt.show()
# Out:
# 4636.00    3
# 4628.00    3
# 4645.00    3
# 4626.00    3
# 4634.00    2
#           ..
# 4616.05    1
# 4626.40    1
# 4646.25    1
# 4627.45    1
# 4638.00    1
# Name: LOW, Length: 80, dtype: int64
